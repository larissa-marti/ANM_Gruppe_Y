# %% [markdown]
# # 1. Import

# %% [markdown]
# ## 1.1 Import Bib

# %%
import pandas as pd

import geopandas as gpd
from shapely.geometry import LineString, Point

from branca.colormap import StepColormap

import folium
import matplotlib.pyplot as plt
from ipywidgets import interact, Dropdown

from folium.features import GeoJsonTooltip

from IPython.display import display

from branca.colormap import linear

import matplotlib.patches as mpatches

import geopandas as gpd

import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

import seaborn as sns
from branca.colormap import linear

# %% [markdown]
# ## 1.2 Import Data

# %%
# csv einlesen
wege = pd.read_csv("generated_data/wege_freizeit_erweitert.csv", sep=";")

# %%
# csv einlesen
etappen = pd.read_csv("generated_data/etappen_freizeit_erweitert.csv", sep=";")

# %%
gemeinden = pd.read_csv("Data/Ortschaftsverzeichnis.csv", sep=";")

# %%
# File path to the Shapefile
shapefile_path = "Data/swissBOUNDARIES3D_1_5_TLM_KANTONSGEBIET.shp"

# Load the Shapefile
shp_data_kanton = gpd.read_file(shapefile_path)

# %%
# File path to the Shapefile
shapefile_path = "Data/swissBOUNDARIES3D_1_5_TLM_HOHEITSGEBIET.shp"

# Load the Shapefile
shp_data_gemeinde = gpd.read_file(shapefile_path)

# %%
# File path to the Shapefile
shapefile_path = (
    "Data/geodaten_landschaftstypologie/Shape/Landschaftstypologie_Schweiz.shp"
)

# Load the Shapefile
shp_data_topologie = gpd.read_file(shapefile_path)

# %%
shp_data_topologie.head()

# %% [markdown]
# # 2. Data bearbeiten

# %%
wege.head()

# %%
wege.columns

# %%
etappen.head()

# %%
etappen.columns

# %%
gemeinden.head()

# %% [markdown]
# # 3. Merge

# %%
# Merge über PLZ: Wohnort PLZ von Wege und PLZ von Gemeinden
wege_gemeinden_merged = wege.merge(
    gemeinden[["PLZ", "Gemeindename"]],  # Nur relevante Spalten für den Merge
    left_on="Wohnort: PLZ",  # Spalte im Wege-Dataset
    right_on="PLZ",  # Spalte im Gemeinden-Dataset
    how="left",  # Alle Wege behalten, auch wenn keine passende Gemeinde gefunden wird
)

# Die Spalte PLZ aus Gemeinden entfernen, falls sie nicht mehr benötigt wird
wege_gemeinden_merged.drop(columns=["PLZ"], inplace=True)

# Duplikate entfernen
wege_gemeinden_merged = wege_gemeinden_merged.drop_duplicates(
    subset=["HHNR", "Wegnummer"]
).reset_index(drop=True)

# Ergebnis anzeigen
wege_gemeinden_merged

# %%
wege_gemeinden_merged.info()

# %% [markdown]
# # 4. Analysen

# %% [markdown]
# ## 4.1 Wege

# %%
shp_data_kanton.head()

# %%
# Zeig mir die unique values der Spalte NAME
shp_data_kanton["NAME"].unique()

# %%
# Mapping von Kantonsnamen zu Kantonskürzeln
kantons_mapping = {
    "Genève": "GE",
    "Thurgau": "TG",
    "Valais": "VS",
    "Aargau": "AG",
    "Schwyz": "SZ",
    "Zürich": "ZH",
    "Obwalden": "OW",
    "Fribourg": "FR",
    "Glarus": "GL",
    "Uri": "UR",
    "Nidwalden": "NW",
    "Solothurn": "SO",
    "Appenzell Ausserrhoden": "AR",
    "Jura": "JU",
    "Graubünden": "GR",
    "Vaud": "VD",
    "Luzern": "LU",
    "Ticino": "TI",
    "Zug": "ZG",
    "Basel-Landschaft": "BL",
    "St. Gallen": "SG",
    "Schaffhausen": "SH",
    "Bern": "BE",
    "Basel-Stadt": "BS",
    "Neuchâtel": "NE",
    "Appenzell Innerrhoden": "AI",
}

# Neue Spalte für die Kantonskürzel hinzufügen
shp_data_kanton["KANTONS_KÜRZEL"] = shp_data_kanton["NAME"].map(kantons_mapping)

# Ergebnisse überprüfen
print(shp_data_kanton[["NAME", "KANTONS_KÜRZEL"]].head())

# %%
wege_gemeinden_merged.head()

# %% [markdown]
# 4.1.1 Gesamtemissionen pro Kanton

# %%
# Sicherstellen, dass alle Daten serialisierbar sind
def prepare_serializable_data(gdf):
    for col in gdf.select_dtypes(include=["datetime64[ns]", "datetime"]).columns:
        gdf[col] = gdf[col].astype(str)  # Konvertiere Timestamp in String
    return gdf


# Funktion, um die Karte für alle Freizeitaktivitäten zu plotten
def plot_map_for_all_activities():
    # Median-Emissionen pro Gemeinde berechnen (ohne Filter)
    median_emissionen_gemeinde = (
        wege_gemeinden_merged.groupby("Gemeindename")["Emissionen"].mean().reset_index()
    )
    median_emissionen_gemeinde.rename(
        columns={"Gemeindename": "NAME", "Emissionen": "Median_Emissionen"},
        inplace=True,
    )

    # Shapefile mit aggregierten Daten verbinden
    shp_data_gemeinde_filtered = shp_data_gemeinde.merge(
        median_emissionen_gemeinde, on="NAME", how="left"
    )

    # Aggregation auf Kantonsebene
    kanton_emissionen = (
        shp_data_gemeinde_filtered.groupby("KANTONSNUM")["Median_Emissionen"]
        .median()
        .reset_index()
    )
    kanton_emissionen.rename(
        columns={
            "KANTONSNUM": "KANTONSNUM",
            "Median_Emissionen": "Median_Emissionen_Kanton",
        },
        inplace=True,
    )

    # Kanton-Shapefile mit aggregierten Daten verbinden
    shp_data_kanton_filtered = shp_data_kanton.merge(
        kanton_emissionen, on="KANTONSNUM", how="left"
    )

    # Konvertieren in WGS84 (für folium erforderlich)
    shp_data_kanton_filtered = shp_data_kanton_filtered.to_crs(epsg=4326)

    # Sicherstellen, dass die Daten JSON-kompatibel sind
    shp_data_kanton_filtered = prepare_serializable_data(shp_data_kanton_filtered)

    # Median-Emissionen im Schweizer Format formatieren
    shp_data_kanton_filtered["Formatted_Emissionen"] = shp_data_kanton_filtered[
        "Median_Emissionen_Kanton"
    ].apply(lambda x: f"{x:,.0f}".replace(",", "'") if not pd.isnull(x) else None)

    # Regenbogen-Farbskala erstellen (basierend auf Emissionen)
    max_emission = shp_data_kanton_filtered["Median_Emissionen_Kanton"].max()
    colormap = linear.RdYlGn_09.scale(0, max_emission)  # Regenbogen-Farbskala
    colormap.caption = "Mittlere Emissionen (kg CO2) pro Kanton"

    # Interaktive Karte erstellen
    m = folium.Map(
        location=[46.8, 8.3],  # Zentrale Position (Schweiz)
        zoom_start=8,  # Zoom-Level
        tiles=None,  # Entferne die Standard-Hintergrundkachel
    )

    # Weißes Hintergrund-Overlay hinzufügen
    folium.TileLayer(
        tiles="https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
        attr="White Background",
        name="White",
        show=False,
        control=False,
        opacity=0,  # Unsichtbar machen, für weißen Hintergrund
    ).add_to(m)

    # GeoJson-Layer hinzufügen, um Kantone und Tooltips anzuzeigen
    folium.GeoJson(
        shp_data_kanton_filtered,
        style_function=lambda feature: {
            "fillColor": (
                "lightgrey"
                if feature["properties"]["Median_Emissionen_Kanton"] is None
                else (
                    "white"
                    if feature["properties"]["Median_Emissionen_Kanton"] == 0
                    else colormap(feature["properties"]["Median_Emissionen_Kanton"])
                )
            ),
            "color": "black",
            "weight": 0.5,
            "fillOpacity": 0.7,
        },
        tooltip=GeoJsonTooltip(
            fields=[
                "NAME",
                "Formatted_Emissionen",
            ],  # Zeige Name und formatierte Emissionen
            aliases=["Kantonsname:", "Mittlere Emissionen (kg CO2):"],  # Überschriften
            localize=True,
        ),
    ).add_to(m)

    # Kantonskürzel als fett geschriebenen Text auf der Karte hinzufügen
    for _, row in shp_data_kanton_filtered.iterrows():
        if row["geometry"].centroid:
            folium.Marker(
                location=[
                    row["geometry"].centroid.y,
                    row["geometry"].centroid.x,
                ],  # Zentrum des Kantons
                icon=folium.DivIcon(
                    html=f'<div style="font-size: 12px; font-weight: bold; color: black; text-align: center;">{row["KANTONS_KÜRZEL"]}</div>'
                ),
            ).add_to(m)

    # Farblegende hinzufügen
    colormap.add_to(m)

    # Rückgabe der Karte
    return m


# Karte direkt anzeigen
m = plot_map_for_all_activities()
display(m)

# %% [markdown]
# Ausgabe in Tonnen:

# %%
# Sicherstellen, dass alle Daten serialisierbar sind
def prepare_serializable_data(gdf):
    for col in gdf.select_dtypes(include=["datetime64[ns]", "datetime"]).columns:
        gdf[col] = gdf[col].astype(str)  # Konvertiere Timestamp in String
    return gdf


# Funktion, um die Karte für alle Freizeitaktivitäten zu plotten
def plot_map_for_all_activities():
    # Median-Emissionen pro Gemeinde berechnen (ohne Filter)
    median_emissionen_gemeinde = (
        wege_gemeinden_merged.groupby("Gemeindename")["Emissionen"].mean().reset_index()
    )
    median_emissionen_gemeinde.rename(
        columns={"Gemeindename": "NAME", "Emissionen": "Median_Emissionen"},
        inplace=True,
    )

    # Shapefile mit aggregierten Daten verbinden
    shp_data_gemeinde_filtered = shp_data_gemeinde.merge(
        median_emissionen_gemeinde, on="NAME", how="left"
    )

    # Aggregation auf Kantonsebene
    kanton_emissionen = (
        shp_data_gemeinde_filtered.groupby("KANTONSNUM")["Median_Emissionen"]
        .median()
        .reset_index()
    )
    kanton_emissionen.rename(
        columns={
            "KANTONSNUM": "KANTONSNUM",
            "Median_Emissionen": "Median_Emissionen_Kanton",
        },
        inplace=True,
    )

    # Kanton-Shapefile mit aggregierten Daten verbinden
    shp_data_kanton_filtered = shp_data_kanton.merge(
        kanton_emissionen, on="KANTONSNUM", how="left"
    )

    # Median-Emissionen in Tonnen umrechnen
    shp_data_kanton_filtered["Median_Emissionen_Kanton"] = (
        shp_data_kanton_filtered["Median_Emissionen_Kanton"] / 1000
    )

    # Konvertieren in WGS84 (für folium erforderlich)
    shp_data_kanton_filtered = shp_data_kanton_filtered.to_crs(epsg=4326)

    # Sicherstellen, dass die Daten JSON-kompatibel sind
    shp_data_kanton_filtered = prepare_serializable_data(shp_data_kanton_filtered)

    # Median-Emissionen im Schweizer Format formatieren (in Tonnen)
    shp_data_kanton_filtered["Formatted_Emissionen"] = shp_data_kanton_filtered[
        "Median_Emissionen_Kanton"
    ].apply(lambda x: f"{x:,.2f} t".replace(",", "'") if not pd.isnull(x) else None)

    # Regenbogen-Farbskala erstellen (basierend auf Emissionen in Tonnen)
    max_emission = shp_data_kanton_filtered["Median_Emissionen_Kanton"].max()
    colormap = linear.RdYlGn_09.scale(0, max_emission)  # Regenbogen-Farbskala
    colormap.caption = "Mittlere Emissionen (t CO2) pro Kanton"

    # Interaktive Karte erstellen
    m = folium.Map(
        location=[46.8, 8.3],  # Zentrale Position (Schweiz)
        zoom_start=8,  # Zoom-Level
        tiles=None,  # Entferne die Standard-Hintergrundkachel
    )

    # Weißes Hintergrund-Overlay hinzufügen
    folium.TileLayer(
        tiles="https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
        attr="White Background",
        name="White",
        show=False,
        control=False,
        opacity=0,  # Unsichtbar machen, für weißen Hintergrund
    ).add_to(m)

    # GeoJson-Layer hinzufügen, um Kantone und Tooltips anzuzeigen
    folium.GeoJson(
        shp_data_kanton_filtered,
        style_function=lambda feature: {
            "fillColor": (
                "lightgrey"
                if feature["properties"]["Median_Emissionen_Kanton"] is None
                else (
                    "white"
                    if feature["properties"]["Median_Emissionen_Kanton"] == 0
                    else colormap(feature["properties"]["Median_Emissionen_Kanton"])
                )
            ),
            "color": "black",
            "weight": 0.5,
            "fillOpacity": 0.7,
        },
        tooltip=GeoJsonTooltip(
            fields=[
                "NAME",
                "Formatted_Emissionen",
            ],  # Zeige Name und formatierte Emissionen
            aliases=["Kantonsname:", "Mittlere Emissionen (t CO2):"],  # Überschriften
            localize=True,
        ),
    ).add_to(m)

    # Kantonskürzel als fett geschriebenen Text auf der Karte hinzufügen
    for _, row in shp_data_kanton_filtered.iterrows():
        if row["geometry"].centroid:
            folium.Marker(
                location=[
                    row["geometry"].centroid.y,
                    row["geometry"].centroid.x,
                ],  # Zentrum des Kantons
                icon=folium.DivIcon(
                    html=f'<div style="font-size: 12px; font-weight: bold; color: black; text-align: center;">{row["KANTONS_KÜRZEL"]}</div>'
                ),
            ).add_to(m)

    # Farblegende hinzufügen
    colormap.add_to(m)

    # Rückgabe der Karte
    return m


# Karte direkt anzeigen
m = plot_map_for_all_activities()
display(m)

# %% [markdown]
# 4.1.2 Gesamtemissionen pro Freizeitkativität und Kanton

# %%
# Sicherstellen, dass alle Daten serialisierbar sind
def prepare_serializable_data(gdf):
    for col in gdf.select_dtypes(include=["datetime64[ns]", "datetime"]).columns:
        gdf[col] = gdf[col].astype(str)  # Konvertiere Timestamp in String
    return gdf


# Funktion, um die Karte basierend auf der Freizeitaktivität zu plotten
def plot_map_by_kanton(activity):
    # Daten für die ausgewählte Freizeitaktivität filtern
    filtered_data = wege_gemeinden_merged[
        wege_gemeinden_merged["Freizeitaktivität"] == activity
    ]

    # Durchschnittliche Emissionen pro Gemeinde berechnen
    avg_emissionen_gemeinde = (
        filtered_data.groupby("Gemeindename")["Emissionen"].mean().reset_index()
    )
    avg_emissionen_gemeinde.rename(
        columns={"Gemeindename": "NAME", "Emissionen": "Avg_Emissionen"}, inplace=True
    )

    # Shapefile mit gefilterten Daten verbinden
    shp_data_gemeinde_filtered = shp_data_gemeinde.merge(
        avg_emissionen_gemeinde, on="NAME", how="left"
    )

    # Aggregation auf Kantonsebene
    kanton_emissionen = (
        shp_data_gemeinde_filtered.groupby("KANTONSNUM")["Avg_Emissionen"]
        .mean()
        .reset_index()
    )
    kanton_emissionen.rename(
        columns={"KANTONSNUM": "KANTONSNUM", "Avg_Emissionen": "Avg_Emissionen_Kanton"},
        inplace=True,
    )

    # Kanton-Shapefile mit aggregierten Daten verbinden
    shp_data_kanton_filtered = shp_data_kanton.merge(
        kanton_emissionen, on="KANTONSNUM", how="left"
    )

    # Konvertieren in WGS84 (für folium erforderlich)
    shp_data_kanton_filtered = shp_data_kanton_filtered.to_crs(epsg=4326)

    # Sicherstellen, dass die Daten JSON-kompatibel sind
    shp_data_kanton_filtered = prepare_serializable_data(shp_data_kanton_filtered)

    # Durchschnittliche Emissionen im Schweizer Format formatieren (mit Runden auf ganze Zahlen)
    shp_data_kanton_filtered["Formatted_Emissionen"] = shp_data_kanton_filtered[
        "Avg_Emissionen_Kanton"
    ].apply(lambda x: f"{x:,.0f}".replace(",", "'") if not pd.isnull(x) else None)

    # Blaue Farbskala erstellen (basierend auf Emissionen)
    max_emission = shp_data_kanton_filtered["Avg_Emissionen_Kanton"].max()
    colormap = linear.Blues_09.scale(0, max_emission)  # Blaue Farbskala
    colormap.caption = "Durchschnittliche Emissionen (kg CO2) pro Kanton"

    # Interaktive Karte erstellen (weißer Hintergrund)
    m = folium.Map(
        location=[46.8, 8.3],  # Zentrale Position (Schweiz)
        zoom_start=8,  # Zoom-Level
        tiles=None,  # Entferne die Standard-Hintergrundkachel
    )

    # Weißes Hintergrund-Overlay hinzufügen
    folium.TileLayer(
        tiles="https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
        attr="White Background",
        name="White Background",
        show=False,
        control=False,
        opacity=0,  # Unsichtbar, um weißen Hintergrund zu haben
    ).add_to(m)

    # GeoJson-Layer hinzufügen, um Kantone und Tooltips anzuzeigen
    folium.GeoJson(
        shp_data_kanton_filtered,
        style_function=lambda feature: {
            "fillColor": (
                "lightgrey"
                if feature["properties"]["Avg_Emissionen_Kanton"] is None
                else (
                    "white"
                    if feature["properties"]["Avg_Emissionen_Kanton"] == 0
                    else colormap(feature["properties"]["Avg_Emissionen_Kanton"])
                )
            ),
            "color": "black",
            "weight": 0.5,
            "fillOpacity": 0.7,
        },
        tooltip=GeoJsonTooltip(
            fields=[
                "NAME",
                "Formatted_Emissionen",
            ],  # Zeige Kanton und formatierte Emissionen
            aliases=[
                "Kantonsname:",
                "Durchschnittliche Emissionen (kg CO2):",
            ],  # Überschriften
            localize=True,
        ),
    ).add_to(m)

    # Kantonskürzel als fett geschriebenen Text auf der Karte hinzufügen
    for _, row in shp_data_kanton_filtered.iterrows():
        if row["geometry"].centroid:
            folium.Marker(
                location=[
                    row["geometry"].centroid.y,
                    row["geometry"].centroid.x,
                ],  # Zentrum des Kantons
                icon=folium.DivIcon(
                    html=f'<div style="font-size: 12px; font-weight: bold; color: black; text-align: center;">{row["KANTONS_KÜRZEL"]}</div>'
                ),
            ).add_to(m)

    # Farblegende hinzufügen
    colormap.add_to(m)

    # Rückgabe der Karte
    return m


# Dropdown mit allen Freizeitaktivitäten erstellen
freizeitaktivitaeten = wege_gemeinden_merged["Freizeitaktivität"].unique()


# Interact korrekt einrichten
def display_map(activity):
    m = plot_map_by_kanton(activity)  # Ruft die Kartenfunktion auf
    display(m)


interact(
    display_map,
    activity=Dropdown(options=freizeitaktivitaeten, description="Freizeitaktivität:"),
)

# %% [markdown]
# 4.1.3 Gesamtemissionen pro Gemeinde

# %%
# Sicherstellen, dass alle Daten serialisierbar sind
def prepare_serializable_data(gdf):
    for col in gdf.select_dtypes(include=["datetime64[ns]", "datetime"]).columns:
        gdf[col] = gdf[col].astype(str)  # Konvertiere Timestamp in String
    return gdf


# Funktion, um die Karte für alle Freizeitaktivitäten zu plotten
def plot_map_for_all_activities():
    # Median-Emissionen pro Gemeinde berechnen (ohne Filter)
    median_emissionen = (
        wege_gemeinden_merged.groupby("Gemeindename")["Emissionen"].mean().reset_index()
    )
    median_emissionen.rename(
        columns={"Gemeindename": "NAME", "Emissionen": "Median_Emissionen"},
        inplace=True,
    )

    # Shapefile mit aggregierten Daten verbinden
    shp_data_filtered = shp_data_gemeinde.merge(
        median_emissionen, on="NAME", how="left"
    )

    # Konvertieren in WGS84 (für folium erforderlich)
    shp_data_filtered = shp_data_filtered.to_crs(epsg=4326)

    # Sicherstellen, dass die Daten JSON-kompatibel sind
    shp_data_filtered = prepare_serializable_data(shp_data_filtered)

    # Median-Emissionen im Schweizer Format formatieren (mit Runden auf ganze Zahlen)
    shp_data_filtered["Formatted_Emissionen"] = shp_data_filtered[
        "Median_Emissionen"
    ].apply(lambda x: f"{x:,.0f}".replace(",", "'") if not pd.isnull(x) else None)

    # Blaue Farbskala erstellen (dunkelblau ab 20'000)
    cutoff_value = 20000  # Schwellenwert für Dunkelblau
    colormap = StepColormap(
        colors=["#f7fbff", "#c6dbef", "#6baed6", "#2171b5", "#08306b"],  # Blautöne
        index=[
            0,
            5000,
            10000,
            15000,
            cutoff_value,
            shp_data_filtered["Median_Emissionen"].max(),
        ],
        vmin=0,
        vmax=shp_data_filtered["Median_Emissionen"].max(),
        caption="Mittlere Emissionen (kg CO2)",
    )

    # Interaktive Karte erstellen (weißer Hintergrund)
    m = folium.Map(
        location=[46.8, 8.3],  # Zentrale Position (Schweiz)
        zoom_start=8,  # Zoom-Level
        tiles=None,  # Entferne die Standard-Hintergrundkachel
    )

    # Weißes Hintergrund-Overlay hinzufügen
    folium.TileLayer(
        tiles="https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
        attr="White Background",
        name="White Background",
        show=False,
        control=False,
        opacity=0,  # Unsichtbar, um einen weißen Hintergrund zu erzeugen
    ).add_to(m)

    # GeoJson-Layer hinzufügen, um Gemeinden und Tooltips anzuzeigen
    folium.GeoJson(
        shp_data_filtered,
        style_function=lambda feature: {
            "fillColor": (
                "black"
                if feature["properties"]["Median_Emissionen"]
                is None  # Muster für fehlende Werte
                else (
                    "white"
                    if feature["properties"]["Median_Emissionen"]
                    == 0  # Weiß für 0 Emissionen
                    else colormap(
                        min(
                            feature["properties"]["Median_Emissionen"], cutoff_value
                        )  # Werte über 20'000 begrenzen
                    )
                )
            ),
            "color": "black",
            "weight": 0.5,
            "fillOpacity": 0.7,
        },
        tooltip=GeoJsonTooltip(
            fields=[
                "NAME",
                "Formatted_Emissionen",
            ],  # Zeige Name und formatierte Emissionen
            aliases=["Gemeindename:", "Mittlere Emissionen (kg CO2):"],  # Überschriften
            localize=True,
        ),
    ).add_to(m)

    # Farblegende hinzufügen
    colormap.add_to(m)

    # Rückgabe der Karte
    return m


# Karte direkt anzeigen
m = plot_map_for_all_activities()
display(m)

# %% [markdown]
# Ausgabe in Tonnen:

# %%
# Sicherstellen, dass alle Daten serialisierbar sind
def prepare_serializable_data(gdf):
    for col in gdf.select_dtypes(include=["datetime64[ns]", "datetime"]).columns:
        gdf[col] = gdf[col].astype(str)  # Konvertiere Timestamp in String
    return gdf


# Funktion, um die Karte für alle Freizeitaktivitäten zu plotten
def plot_map_for_all_activities():
    # Median-Emissionen pro Gemeinde berechnen (ohne Filter) und in Tonnen umrechnen
    median_emissionen = (
        wege_gemeinden_merged.groupby("Gemeindename")["Emissionen"].mean().reset_index()
    )
    median_emissionen.rename(
        columns={"Gemeindename": "NAME", "Emissionen": "Median_Emissionen"},
        inplace=True,
    )
    median_emissionen["Median_Emissionen"] = median_emissionen["Median_Emissionen"] / 1000  # Umrechnung in Tonnen

    # Shapefile mit aggregierten Daten verbinden
    shp_data_filtered = shp_data_gemeinde.merge(
        median_emissionen, on="NAME", how="left"
    )

    # Konvertieren in WGS84 (für folium erforderlich)
    shp_data_filtered = shp_data_filtered.to_crs(epsg=4326)

    # Sicherstellen, dass die Daten JSON-kompatibel sind
    shp_data_filtered = prepare_serializable_data(shp_data_filtered)

    # Median-Emissionen im Schweizer Format formatieren (mit Runden auf zwei Dezimalstellen)
    shp_data_filtered["Formatted_Emissionen"] = shp_data_filtered[
        "Median_Emissionen"
    ].apply(lambda x: f"{x:,.2f} t".replace(",", "'") if not pd.isnull(x) else None)

    # Blaue Farbskala erstellen (dunkelblau ab 20 Tonnen)
    cutoff_value = 20  # Schwellenwert für Dunkelblau (in Tonnen)
    colormap = StepColormap(
        colors=["#f7fbff", "#c6dbef", "#6baed6", "#2171b5", "#08306b"],  # Blautöne
        index=[
            0,
            5,
            10,
            15,
            cutoff_value,
            shp_data_filtered["Median_Emissionen"].max(),
        ],
        vmin=0,
        vmax=shp_data_filtered["Median_Emissionen"].max(),
        caption="Mittlere Emissionen (t CO2)",
    )

    # Interaktive Karte erstellen (weißer Hintergrund)
    m = folium.Map(
        location=[46.8, 8.3],  # Zentrale Position (Schweiz)
        zoom_start=8,  # Zoom-Level
        tiles=None,  # Entferne die Standard-Hintergrundkachel
    )

    # Weißes Hintergrund-Overlay hinzufügen
    folium.TileLayer(
        tiles="https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
        attr="White Background",
        name="White Background",
        show=False,
        control=False,
        opacity=0,  # Unsichtbar, um einen weißen Hintergrund zu erzeugen
    ).add_to(m)

    # GeoJson-Layer hinzufügen, um Gemeinden und Tooltips anzuzeigen
    folium.GeoJson(
        shp_data_filtered,
        style_function=lambda feature: {
            "fillColor": (
                "black"
                if feature["properties"]["Median_Emissionen"]
                is None  # Muster für fehlende Werte
                else (
                    "white"
                    if feature["properties"]["Median_Emissionen"]
                    == 0  # Weiß für 0 Emissionen
                    else colormap(
                        min(
                            feature["properties"]["Median_Emissionen"], cutoff_value
                        )  # Werte über 20 Tonnen begrenzen
                    )
                )
            ),
            "color": "black",
            "weight": 0.5,
            "fillOpacity": 0.7,
        },
        tooltip=GeoJsonTooltip(
            fields=[
                "NAME",
                "Formatted_Emissionen",
            ],  # Zeige Name und formatierte Emissionen
            aliases=["Gemeindename:", "Mittlere Emissionen (t CO2):"],  # Überschriften
            localize=True,
        ),
    ).add_to(m)

    # Farblegende hinzufügen
    colormap.add_to(m)

    # Rückgabe der Karte
    return m


# Karte direkt anzeigen
m = plot_map_for_all_activities()
display(m)

# %% [markdown]
# 4.1.4 Gesamtemissionen pro Freizeitaktivität und Gemeinde

# %%
# Sicherstellen, dass alle Daten serialisierbar sind
def prepare_serializable_data(gdf):
    for col in gdf.select_dtypes(include=["datetime64[ns]", "datetime"]).columns:
        gdf[col] = gdf[col].astype(str)  # Konvertiere Timestamp in String
    return gdf


# Funktion, um die Karte basierend auf der Freizeitaktivität zu plotten
def plot_map(activity):
    # Daten für die ausgewählte Freizeitaktivität filtern
    filtered_data = wege_gemeinden_merged[
        wege_gemeinden_merged["Freizeitaktivität"] == activity
    ]

    # Durchschnittliche Emissionen pro Gemeinde berechnen
    avg_emissionen = (
        filtered_data.groupby("Gemeindename")["Emissionen"].mean().reset_index()
    )
    avg_emissionen.rename(
        columns={"Gemeindename": "NAME", "Emissionen": "Avg_Emissionen"}, inplace=True
    )

    # Shapefile mit gefilterten Daten verbinden
    shp_data_filtered = shp_data_gemeinde.merge(avg_emissionen, on="NAME", how="left")

    # Konvertieren in WGS84 (für folium erforderlich)
    shp_data_filtered = shp_data_filtered.to_crs(epsg=4326)

    # Sicherstellen, dass die Daten JSON-kompatibel sind
    shp_data_filtered = prepare_serializable_data(shp_data_filtered)

    # Durchschnittliche Emissionen im Schweizer Format formatieren (mit Runden auf ganze Zahlen)
    shp_data_filtered["Formatted_Emissionen"] = shp_data_filtered[
        "Avg_Emissionen"
    ].apply(lambda x: f"{x:,.0f}".replace(",", "'") if not pd.isnull(x) else None)

    # Blaue Farbskala erstellen (dunkelblau ab 20'000)
    cutoff_value = 20000  # Schwellenwert für Dunkelblau
    colormap = StepColormap(
        colors=["#f7fbff", "#c6dbef", "#6baed6", "#2171b5", "#08306b"],  # Blautöne
        index=[
            0,
            5000,
            10000,
            15000,
            cutoff_value,
            shp_data_filtered["Avg_Emissionen"].max(),
        ],
        vmin=0,
        vmax=shp_data_filtered["Avg_Emissionen"].max(),
        caption="Durchschnittliche Emissionen (kg CO2)",
    )

    # Interaktive Karte erstellen (weißer Hintergrund)
    m = folium.Map(
        location=[46.8, 8.3],  # Zentrale Position (Schweiz)
        zoom_start=8,  # Zoom-Level
        tiles=None,  # Entferne die Standard-Hintergrundkachel
    )

    # Weißes Hintergrund-Overlay hinzufügen
    folium.TileLayer(
        tiles="https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png",
        attr="White Background",
        name="White Background",
        show=False,
        control=False,
        opacity=0,  # Unsichtbar, um den Hintergrund weiß zu machen
    ).add_to(m)

    # GeoJson-Layer hinzufügen, um Gemeinden und Tooltips anzuzeigen
    folium.GeoJson(
        shp_data_filtered,
        style_function=lambda feature: {
            "fillColor": (
                "black"
                if feature["properties"]["Avg_Emissionen"] is None
                else (
                    "white"
                    if feature["properties"]["Avg_Emissionen"] == 0
                    else colormap(
                        min(
                            feature["properties"]["Avg_Emissionen"], cutoff_value
                        )  # Werte über 20'000 begrenzen
                    )
                )
            ),
            "color": "black",
            "weight": 0.5,
            "fillOpacity": 0.7,
        },
        tooltip=GeoJsonTooltip(
            fields=[
                "NAME",
                "Formatted_Emissionen",
            ],  # Zeige Name und formatierte Emissionen
            aliases=[
                "Gemeindename:",
                "Durchschnittliche Emissionen (kg CO2):",
            ],  # Überschriften
            localize=True,
        ),
    ).add_to(m)

    # Farblegende hinzufügen
    colormap.add_to(m)

    # Rückgabe der Karte
    return m


# Dropdown mit allen Freizeitaktivitäten erstellen
freizeitaktivitaeten = wege_gemeinden_merged["Freizeitaktivität"].unique()


# Interact korrekt einrichten
def display_map(activity):
    m = plot_map(activity)  # Ruft die Kartenfunktion auf
    display(m)


interact(
    display_map,
    activity=Dropdown(options=freizeitaktivitaeten, description="Freizeitaktivität:"),
)

# %%
# Überprüfen, ob wichtige Spalten keine fehlenden Werte enthalten
required_columns = [
    "Start_X",
    "Start_Y",
    "Ziel_X",
    "Ziel_Y",
    "Freizeitaktivität",
    "Emissionen",
]
data_cleaned = wege.dropna(subset=required_columns)
# Geometrien erstellen: Start- und Zielpunkte sowie Linien
data_cleaned["Start_Point"] = data_cleaned.apply(
    lambda row: Point(row["Start_X"], row["Start_Y"]), axis=1
)
data_cleaned["End_Point"] = data_cleaned.apply(
    lambda row: Point(row["Ziel_X"], row["Ziel_Y"]), axis=1
)
data_cleaned["Route"] = data_cleaned.apply(
    lambda row: LineString([row["Start_Point"], row["End_Point"]]), axis=1
)

# In ein GeoDataFrame umwandeln
gdf = gpd.GeoDataFrame(data_cleaned, geometry="Route", crs="EPSG:4326")

# %% [markdown]
# 4.1.5 Aufteilung suburban, urban etc.

# %% [markdown]
# Quelle: https://www.are.admin.ch/are/de/home/agglomerationen-laendliche-raeume/grundlagen-und-daten/landschaftstypologie-schweiz.html

# %%
shp_data_topologie.head()

# %%
wege_gemeinden_merged.head()

# %%
# Karte plotten
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Regionen in unterschiedlichen Farben darstellen
shp_data_topologie.plot(
    column="OBJECT_NR",  # Spalte, die Regionen unterscheidet (z. B. OBJECT_NR oder NAME_DE)
    cmap="tab20",  # Farbpalette für unterschiedliche Farben
    legend=False,  # Keine Legende anzeigen
    ax=ax,  # Achse
)

# Titel und Achsen entfernen
ax.set_title("Karte der Regionen mit zufälligen Farben", fontsize=16)
ax.axis("off")

# Karte anzeigen
plt.show()

# %%
# Lade wege_gemeinden_merged (CSV, falls es so vorliegt)
wege_gemeinden = wege_gemeinden_merged

# Wohnort-Koordinaten in Geometrie umwandeln
wege_gemeinden["geometry"] = gpd.points_from_xy(
    wege_gemeinden["Wohnort X-Koordinate"], wege_gemeinden["Wohnort Y-Koordinate"]
)

# GeoDataFrame erstellen
wege_gemeinden_geo = gpd.GeoDataFrame(wege_gemeinden, geometry="geometry")

# CRS setzen (falls Koordinaten WGS84 sind)
wege_gemeinden_geo = wege_gemeinden_geo.set_crs("EPSG:4326")  # WGS84

# %%
wege_gemeinden_geo = wege_gemeinden_geo.to_crs(
    "EPSG:21781"
)  # Koordinatensystem anpassen

# %%
# Spatial Join: Wohnorte den Regionen zuordnen
merged_data = gpd.sjoin(
    wege_gemeinden_geo, shp_data_topologie, how="inner", predicate="within"
)

# %%
# Durchschnittliche Emissionen pro Region (NAME_DE) berechnen
emission_avg = merged_data.groupby("NAME_DE")["Emissionen"].mean().reset_index()

# Durchschnittswerte ins Shape-File zurückmergen
shp_data_with_emissions = shp_data_topologie.merge(
    emission_avg, on="NAME_DE", how="left"
)

# %%
# Regionen und Emissionen extrahieren und nach Emissionen absteigend sortieren
unique_regions = (
    shp_data_with_emissions[["NAME_DE", "Emissionen"]]
    .dropna()
    .drop_duplicates()
    .sort_values(by="Emissionen", ascending=False)  # Sortierung nach Emissionen
)

# Manuelle Legende vorbereiten
patches = [
    mpatches.Patch(
        color=color, label=f"{row.NAME_DE}: {row.Emissionen:.2f} ⌀ Emissionen"
    )
    for row, color in zip(unique_regions.itertuples(), plt.cm.tab20.colors)
]

# Karte plotten
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Regionen basierend auf NAME_DE einfärben
shp_data_with_emissions.plot(column="NAME_DE", cmap="tab20", legend=False, ax=ax)

# Titel hinzufügen
ax.set_title("Regionenkarte mit durchschnittlichen Emissionen", fontsize=16)

# Legende außerhalb des Plots platzieren und auf mehrere Spalten verteilen
plt.legend(
    handles=patches,
    loc="center left",
    bbox_to_anchor=(1, 0.5),  # Legende außerhalb des Plots
    title="Regionen und Emissionen (absteigend sortiert)",
    fontsize=8,
    ncol=2,  # Anzahl der Spalten
)

# Achsen entfernen
ax.axis("off")

# Karte anzeigen
plt.show()

# %% [markdown]
# 4.1.6 Aufteilung suburban, urban etc.  2.0

# %% [markdown]
# Quelle: https://data.geo.admin.ch/browser/index.html#/collections/ch.are.gemeindetypen/items/gemeindetypen?.asset=asset-gemeindetypen_2056.gpkg

# %%
from fiona import listlayers

# Liste der Layer anzeigen
path_to_gpkg = "Data/gemeindetypen_2056.gpkg"  # Pfad zur Datei
layers = listlayers(path_to_gpkg)
print("Verfügbare Layer:", layers)

# %%
# Step 1: Das neue GeoPackage-Dataset einlesen
path_to_gpkg = "Data/gemeindetypen_2056.gpkg"  # Pfad zur Datei
layer_name = "ARE_GemTyp00_9"  # Layer-Name aus dem GeoPackage
new_gpkg_data = gpd.read_file(path_to_gpkg, layer=layer_name)

# Wohnortdaten einlesen (wege_gemeinden_merged)
wege_gemeinden = wege_gemeinden_merged

# Wohnort-Koordinaten in Geometrie umwandeln
wege_gemeinden["geometry"] = gpd.points_from_xy(
    wege_gemeinden["Wohnort X-Koordinate"], wege_gemeinden["Wohnort Y-Koordinate"]
)
wege_gemeinden_geo = gpd.GeoDataFrame(
    wege_gemeinden, geometry="geometry", crs="EPSG:4326"
)

# Transformiere die Wohnort-Daten ins Koordinatensystem des GeoPackage-Datensatzes
wege_gemeinden_geo = wege_gemeinden_geo.to_crs(new_gpkg_data.crs)

# Regionen ohne Wohnortpunkte explizit identifizieren (nach Spatial Join)
merged_data = gpd.sjoin(
    new_gpkg_data, wege_gemeinden_geo, how="left", predicate="intersects"
)

# Gemeinden OHNE Wohnortpunkte (fehlende Geometrien aus left join)
fehlende_gemeinden = merged_data[merged_data["index_right"].isna()]


# Step 3: Durchschnittliche Emissionen pro Region berechnen
emission_avg = merged_data.groupby("NAME")["Emissionen"].mean().reset_index()

# Durchschnittswerte ins GeoPackage-Dataset zurückmergen
new_gpkg_data_with_emissions = new_gpkg_data.merge(emission_avg, on="NAME", how="left")

# Manuelle Farben für jede Kategorie definieren
region_colors = {
    "Agrargemeinden": "#1f77b4",  # Blau
    "Gürtel der Grosszentren": "#aec7e8",  # Hellblau
    "Periurbane ländliche Gemeinden": "#ff7f0e",  # Orange
    "Kleinzentren": "yellow",  # Hellorange
    "Nebenzentren der Grosszentren": "#2ca02c",  # Grün
    "Gürtel der Mittelzentren": "#98df8a",  # Hellgrün
    "Mittelzentren": "#d62728",  # Rot
    "Touristische Gemeinden": "#ff9896",  # Rosa
    "Grosszentren": "#9467bd",  # Lila
}

# Step 4: Karte erstellen
fig, ax = plt.subplots(1, 1, figsize=(15, 10))


# Regionen mit Emissionswerten einfärben
for region_name, color in region_colors.items():
    new_gpkg_data_with_emissions[
        (new_gpkg_data_with_emissions["NAME"] == region_name)
        & (~new_gpkg_data_with_emissions["Emissionen"].isna())
    ].plot(color=color, edgecolor="none", ax=ax)

# Manuelle Legende vorbereiten mit durchschnittlichen Emissionen
patches = [
    mpatches.Patch(
        color=color,
        label=f"{region_name}: {new_gpkg_data_with_emissions.loc[new_gpkg_data_with_emissions['NAME'] == region_name, 'Emissionen'].mean():.2f} ⌀ Emissionen",
    )
    for region_name, color in region_colors.items()
]


# Titel hinzufügen
ax.set_title("Regionenkarte mit durchschnittlichen Emissionen (NAME)", fontsize=16)

# Legende anzeigen
plt.legend(
    handles=patches,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
    title="Regionen und Emissionen",
    fontsize=8,
    ncol=1,
)

# Achsen entfernen
ax.axis("off")

# Karte anzeigen
plt.show()

# %% [markdown]
# Ausgabe in Tonnen:

# %%
# Step 1: Das neue GeoPackage-Dataset einlesen
path_to_gpkg = "Data/gemeindetypen_2056.gpkg"  # Pfad zur Datei
layer_name = "ARE_GemTyp00_9"  # Layer-Name aus dem GeoPackage
new_gpkg_data = gpd.read_file(path_to_gpkg, layer=layer_name)

# Wohnortdaten einlesen (wege_gemeinden_merged)
wege_gemeinden = wege_gemeinden_merged

# Wohnort-Koordinaten in Geometrie umwandeln
wege_gemeinden["geometry"] = gpd.points_from_xy(
    wege_gemeinden["Wohnort X-Koordinate"], wege_gemeinden["Wohnort Y-Koordinate"]
)
wege_gemeinden_geo = gpd.GeoDataFrame(
    wege_gemeinden, geometry="geometry", crs="EPSG:4326"
)

# Transformiere die Wohnort-Daten ins Koordinatensystem des GeoPackage-Datensatzes
wege_gemeinden_geo = wege_gemeinden_geo.to_crs(new_gpkg_data.crs)

# Regionen ohne Wohnortpunkte explizit identifizieren (nach Spatial Join)
merged_data = gpd.sjoin(
    new_gpkg_data, wege_gemeinden_geo, how="left", predicate="intersects"
)

# Gemeinden OHNE Wohnortpunkte (fehlende Geometrien aus left join)
fehlende_gemeinden = merged_data[merged_data["index_right"].isna()]

# Step 3: Durchschnittliche Emissionen pro Region berechnen (in Tonnen)
merged_data["Emissionen_Tonnen"] = merged_data["Emissionen"] / 1000  # Umrechnung in Tonnen
emission_avg = merged_data.groupby("NAME")["Emissionen_Tonnen"].mean().reset_index()

# Durchschnittswerte ins GeoPackage-Dataset zurückmergen
new_gpkg_data_with_emissions = new_gpkg_data.merge(emission_avg, on="NAME", how="left")

# Manuelle Farben für jede Kategorie definieren
region_colors = {
    "Agrargemeinden": "#1f77b4",  # Blau
    "Gürtel der Grosszentren": "#aec7e8",  # Hellblau
    "Periurbane ländliche Gemeinden": "#ff7f0e",  # Orange
    "Kleinzentren": "yellow",  # Hellorange
    "Nebenzentren der Grosszentren": "#2ca02c",  # Grün
    "Gürtel der Mittelzentren": "#98df8a",  # Hellgrün
    "Mittelzentren": "#d62728",  # Rot
    "Touristische Gemeinden": "#ff9896",  # Rosa
    "Grosszentren": "#9467bd",  # Lila
}

# Step 4: Karte erstellen
fig, ax = plt.subplots(1, 1, figsize=(15, 10))

# Regionen mit Emissionswerten einfärben
for region_name, color in region_colors.items():
    new_gpkg_data_with_emissions[
        (new_gpkg_data_with_emissions["NAME"] == region_name)
        & (~new_gpkg_data_with_emissions["Emissionen_Tonnen"].isna())
    ].plot(color=color, edgecolor="none", ax=ax)

# Manuelle Legende vorbereiten mit durchschnittlichen Emissionen
patches = [
    mpatches.Patch(
        color=color,
        label=f"{region_name}: {new_gpkg_data_with_emissions.loc[new_gpkg_data_with_emissions['NAME'] == region_name, 'Emissionen_Tonnen'].mean():.2f}t ⌀ Emissionen",
    )
    for region_name, color in region_colors.items()
]

# Titel hinzufügen
ax.set_title("Regionenkarte mit durchschnittlichen Emissionen in Tonnen (NAME)", fontsize=16)

# Legende anzeigen
plt.legend(
    handles=patches,
    loc="center left",
    bbox_to_anchor=(1, 0.5),
    title="Regionen und Emissionen",
    fontsize=8,
    ncol=1,
)

# Achsen entfernen
ax.axis("off")

# Karte anzeigen
plt.show()

# %%
wege_gemeinden_geo

# %%
# Überprüfen, ob Polygone mit leerer Geometrie existieren
empty_polygons = new_gpkg_data_with_emissions["geometry"].is_empty
print("Leere Polygone:", new_gpkg_data_with_emissions[empty_polygons])

# Überprüfen, ob 'NAME' fehlt
missing_name = new_gpkg_data_with_emissions["NAME"].isna()
print("Fehlende NAME-Werte:", new_gpkg_data_with_emissions[missing_name])

# %% [markdown]
# Boxplots je Typologie

# %%
# Step 1: Filter the data to include only up to the 95th percentile of emissions
percentile_95 = merged_data["Emissionen"].quantile(0.95)
filtered_data = merged_data[merged_data["Emissionen"] <= percentile_95]

# Step 2: Create a boxplot for emissions grouped by Typologie (NAME)
plt.figure(figsize=(12, 8))
sns.boxplot(data=filtered_data, x="NAME", y="Emissionen", palette="tab10")

# Customize the plot
plt.title("Boxplot der Emissionen je Typologie (bis zum 95. Perzentil)", fontsize=16)
plt.xlabel("Typologie", fontsize=12)
plt.ylabel("Emissionen (kg CO2)", fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis="y", linestyle="--", alpha=0.7)  # Add grid lines for y-axis

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Merge

# %%
# Räumlicher Join
result = gpd.sjoin(wege_gemeinden_geo, new_gpkg_data, how="left", predicate="within")

# "NAME"-Spalte hinzufügen
wege_gemeinden_geo["Typologie"] = result["NAME"]

# %%
wege_gemeinden_geo["Typologie"].value_counts()

# %%
wege_gemeinden_geo

# %%
# Referenzkategorie definieren
reference_category = "Grosszentren"

# Dummy-Variablen erstellen
dummy_data = pd.get_dummies(wege_gemeinden_geo["Typologie"], drop_first=False)

# Referenzkategorie entfernen
dummy_data = dummy_data.drop(columns=[reference_category])

# %%
# Zielvariable und Prädiktoren definieren
X = dummy_data  # Dummy-Variablen außer der Referenz
y = wege_gemeinden_geo["Emissionen"]

# Konstanten-Term hinzufügen (Intercept)
X = sm.add_constant(X)

# Regression durchführen
model = sm.OLS(y, X).fit()

# Ergebnisse anzeigen
print(model.summary())

# %%
# Koeffizienten und Konfidenzintervalle extrahieren
coefficients = model.params
conf_int = model.conf_int()
conf_int.columns = ["lower", "upper"]

# Daten vorbereiten
coef_df = pd.DataFrame(
    {
        "category": coefficients.index,
        "coefficient": coefficients.values,
        "lower": conf_int["lower"].values,
        "upper": conf_int["upper"].values,
    }
)

# Nur Dummy-Variablen plotten (ohne den Intercept)
coef_df = coef_df[coef_df["category"] != "const"]

# Sortiere nach Koeffizienten aufsteigend
coef_df = coef_df.sort_values("coefficient")

# Plot erstellen
plt.figure(figsize=(8, 5))
plt.errorbar(
    coef_df["category"],
    coef_df["coefficient"],
    yerr=[
        coef_df["coefficient"] - coef_df["lower"],
        coef_df["upper"] - coef_df["coefficient"],
    ],
    fmt="o",
    capsize=5,
    color="blue",
    label="Koeffizienten mit Konfidenzintervallen",
)

plt.axhline(0, color="gray", linestyle="--", linewidth=0.8)  # Null-Linie
plt.xticks(rotation=90)
plt.xlabel("Kategorie")
plt.ylabel("Koeffizient")
plt.title("Koeffizienten und Konfidenzintervalle je Kategorie")
plt.tight_layout()
plt.show()

# %%
wege_gemeinden_geo.to_csv(
    "generated_data/wege_gemeinden_geo.csv", index=False, sep=";", encoding="utf-8"
)
